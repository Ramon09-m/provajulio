# %%
import pandas as pd



dicti = { "hora_1":None,"hora_2":None,"hora_3":None, "hora_4":None,"hora_5":None,"hora_6":None, "hora_7":None,"hora_8":None,"hora_9":None, "hora_10":None,"us-east-1":None, "us-west-2":None, "eu-central-1":None, "sa-east-1":None, " ap-southeast-1":None }

df_dic = pd.DataFrame([dicti])
df_dic
# Out:
#   hora_1 hora_2 hora_3 hora_4 hora_5 hora_6 hora_7 hora_8 hora_9 hora_10  \
# 0   None   None   None   None   None   None   None   None   None    None
#
#   us-east-1 us-west-2 eu-central-1 sa-east-1  ap-southeast-1
# 0      None      None         None      None            None
